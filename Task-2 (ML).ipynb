# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv("tesla-stock-price.csv")

# %%
data.head()
# Out:
#          date   close         volume    open    high       low
# 0       11:34  270.49      4,787,699  264.50  273.88  262.2400
# 1  2018/10/15  259.59   6189026.0000  259.06  263.28  254.5367
# 2  2018/10/12  258.78   7189257.0000  261.00  261.99  252.0100
# 3  2018/10/11  252.23   8128184.0000  257.53  262.25  249.0300
# 4  2018/10/10  256.88  12781560.0000  264.61  265.51  247.7700

# %%
data.tail()
# Out:
#            date   close         volume    open      high     low
# 752  2015/10/21  210.09   4177956.0000  211.99  214.8100  208.80
# 753  2015/10/20  213.03  14877020.0000  227.72  228.6000  202.00
# 754  2015/10/19  228.10   2506836.0000  226.50  231.1500  224.94
# 755  2015/10/16  227.01   4327574.0000  223.04  230.4805  222.87
# 756  2015/10/15  221.31   2835920.0000  216.43  221.7300  213.70

# %%
data.shape
# Out:
# (757, 6)

# %%
data.describe()
# Out:
#             close        open        high         low
# count  757.000000  757.000000  757.000000  757.000000
# mean   272.645614  272.760659  277.122776  268.017399
# std     58.378585   58.449827   59.194761   57.515736
# min    143.670000  142.320000  154.970000  141.050000
# 25%    219.560000  219.640000  222.569000  216.080000
# 50%    277.450000  277.625000  280.789900  273.550000
# 75%    322.690000  321.560000  327.120000  316.560100
# max    385.000000  386.690000  389.610000  379.345000

# %%
data.columns
# Out:
# Index(['date', 'close', 'volume', 'open', 'high', 'low'], dtype='object')

# %%
data.nunique()
# Out:
# date      757
# close     741
# volume    757
# open      720
# high      734
# low       724
# dtype: int64

# %%
data["date"].unique()
# Out:
# array(['11:34', '2018/10/15', '2018/10/12', '2018/10/11', '2018/10/10',
#        '2018/10/09', '2018/10/08', '2018/10/05', '2018/10/04',
#        '2018/10/03', '2018/10/02', '2018/10/01', '2018/09/28',
#        '2018/09/27', '2018/09/26', '2018/09/25', '2018/09/24',
#        '2018/09/21', '2018/09/20', '2018/09/19', '2018/09/18',
#        '2018/09/17', '2018/09/14', '2018/09/13', '2018/09/12',
#        '2018/09/11', '2018/09/10', '2018/09/07', '2018/09/06',
#        '2018/09/05', '2018/09/04', '2018/08/31', '2018/08/30',
#        '2018/08/29', '2018/08/28', '2018/08/27', '2018/08/24',
#        '2018/08/23', '2018/08/22', '2018/08/21', '2018/08/20',
#        '2018/08/17', '2018/08/16', '2018/08/15', '2018/08/14',
#        '2018/08/13', '2018/08/10', '2018/08/09', '2018/08/08',
#        '2018/08/07', '2018/08/06', '2018/08/03', '2018/08/02',
#        '2018/08/01', '2018/07/31', '2018/07/30', '2018/07/27',
#        '2018/07/26', '2018/07/25', '2018/07/24', '2018/07/23',
# ...

# %%
data["close"].unique()
# Out:
# array([270.49 , 259.59 , 258.78 , 252.23 , 256.88 , 262.8  , 250.56 ,
#        261.95 , 281.83 , 294.8  , 301.02 , 310.7  , 264.77 , 307.52 ,
#        309.58 , 300.99 , 299.68 , 299.1  , 298.33 , 299.02 , 284.96 ,
#        294.84 , 295.2  , 289.46 , 290.54 , 279.44 , 285.5  , 263.24 ,
#        280.95 , 280.74 , 288.95 , 301.66 , 303.15 , 305.01 , 311.86 ,
#        319.27 , 322.82 , 320.1  , 321.64 , 321.9  , 308.44 , 305.5  ,
#        335.45 , 338.69 , 347.64 , 356.41 , 355.49 , 352.45 , 370.34 ,
#        379.57 , 341.99 , 348.17 , 349.54 , 300.84 , 298.14 , 290.17 ,
#        297.18 , 306.65 , 308.74 , 297.43 , 303.2  , 313.58 , 320.23 ,
#        323.85 , 322.69 , 310.1  , 318.87 , 316.71 , 318.96 , 322.47 ,
#        318.51 , 308.9  , 309.16 , 310.86 , 335.07 , 342.95 , 349.93 ,
#        344.5  , 342.   , 333.01 , 333.63 , 347.51 , 362.22 , 352.55 ,
#        370.83 , 358.17 , 357.72 , 344.78 , 342.77 , 332.1  , 317.66 ,
# ...

# %%
data.isnull().sum()
# Out:
# date      0
# close     0
# volume    0
# open      0
# high      0
# low       0
# dtype: int64

# %%
student = data.drop(['date','close'],axis = 1)

# %%
student.head(10)
# Out:
#           volume    open      high       low
# 0      4,787,699  264.50  273.8800  262.2400
# 1   6189026.0000  259.06  263.2800  254.5367
# 2   7189257.0000  261.00  261.9900  252.0100
# 3   8128184.0000  257.53  262.2500  249.0300
# 4  12781560.0000  264.61  265.5100  247.7700
# 5  12037780.0000  255.25  266.7700  253.3000
# 6  13371180.0000  264.52  267.7599  249.0000
# 7  17900710.0000  274.65  274.8800  260.0000
# 8   9638885.0000  293.95  294.0000  277.6700
# 9   7982272.0000  303.33  304.6000  291.5700

# %%
sns.pairplot(student)

# %%
sns.relplot(x='open',y='high',data=student)

# %%
sns.distplot(student['open'])
# Out:
# C:\Users\saitejamotukuri\AppData\Local\Temp\ipykernel_19796\1341147830.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(student['open'])
# <Axes: xlabel='open', ylabel='Density'>

# %%
sns.distplot(student['high'])
# Out:
# C:\Users\saitejamotukuri\AppData\Local\Temp\ipykernel_19796\1316867262.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(student['high'])
# <Axes: xlabel='high', ylabel='Density'>

# %%
sns.catplot(x='high', kind='box', data=student)
